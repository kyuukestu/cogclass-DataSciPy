# %%
import plottingVectors as pv
import numpy as np

u = np.array([1,0])
v = np.array([0,1])

z = np.add(u, v)

x = np.array([0, np.pi/2, np.pi])
y = np.sin(x)

pv.plot_vec_one(u, z, v)
pv.plot_sine(x, y)
# Out:
# /Users/cloudyskyloftymoon/Desktop/DataSciPy/plottingVectors.py:17: RuntimeWarning: divide by zero encountered in divide
#   div = np.divide(u, v)
